# %%
# !unzip PyGame-Learning-Environment.zip
# Out:
# Archive:  PyGame-Learning-Environment.zip
#    creating: PyGame-Learning-Environment/
#    creating: PyGame-Learning-Environment/ple/
#   inflating: PyGame-Learning-Environment/ple/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/PyGame-Learning-Environment/
#    creating: __MACOSX/PyGame-Learning-Environment/ple/
#   inflating: __MACOSX/PyGame-Learning-Environment/ple/._.DS_Store
#   inflating: PyGame-Learning-Environment/ple/ple.py
#   inflating: PyGame-Learning-Environment/ple/__init__.py
#    creating: PyGame-Learning-Environment/ple/__pycache__/
#   inflating: PyGame-Learning-Environment/ple/__pycache__/ple.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/__pycache__/__init__.cpython-37.pyc
#    creating: PyGame-Learning-Environment/ple/games/
#   inflating: PyGame-Learning-Environment/ple/games/raycastmaze.py
#   inflating: PyGame-Learning-Environment/ple/games/puckworld.py
#   inflating: PyGame-Learning-Environment/ple/games/.DS_Store
#    creating: __MACOSX/PyGame-Learning-Environment/ple/games/
#   inflating: __MACOSX/PyGame-Learning-Environment/ple/games/._.DS_Store
#   inflating: PyGame-Learning-Environment/ple/games/primitives.py
#   inflating: PyGame-Learning-Environment/ple/games/pixelcopter.py
#   inflating: PyGame-Learning-Environment/ple/games/__init__.py
#   inflating: PyGame-Learning-Environment/ple/games/snake.py
#    creating: PyGame-Learning-Environment/ple/games/utils/
#   inflating: PyGame-Learning-Environment/ple/games/utils/vec2d.py
#   inflating: PyGame-Learning-Environment/ple/games/utils/.DS_Store
#    creating: __MACOSX/PyGame-Learning-Environment/ple/games/utils/
#   inflating: __MACOSX/PyGame-Learning-Environment/ple/games/utils/._.DS_Store
#   inflating: PyGame-Learning-Environment/ple/games/utils/__init__.py
#    creating: PyGame-Learning-Environment/ple/games/utils/__pycache__/
#   inflating: PyGame-Learning-Environment/ple/games/utils/__pycache__/vec2d.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/utils/__pycache__/__init__.cpython-37.pyc
#    creating: PyGame-Learning-Environment/ple/games/__pycache__/
#   inflating: PyGame-Learning-Environment/ple/games/__pycache__/pixelcopter.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/__pycache__/waterworld.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/__pycache__/pong.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/__pycache__/raycastmaze.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/__pycache__/snake.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/__pycache__/puckworld.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/__pycache__/raycast.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/__pycache__/__init__.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/__pycache__/catcher.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/__pycache__/primitives.cpython-37.pyc
#    creating: PyGame-Learning-Environment/ple/games/doom/
#   inflating: PyGame-Learning-Environment/ple/games/doom/doom.py
#   inflating: PyGame-Learning-Environment/ple/games/doom/__init__.py
#    creating: PyGame-Learning-Environment/ple/games/doom/__pycache__/
#   inflating: PyGame-Learning-Environment/ple/games/doom/__pycache__/doom.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/doom/__pycache__/__init__.cpython-37.pyc
#    creating: PyGame-Learning-Environment/ple/games/doom/assets/
#    creating: PyGame-Learning-Environment/ple/games/doom/assets/cfg/
#   inflating: PyGame-Learning-Environment/ple/games/doom/assets/cfg/my_way_home.cfg
#   inflating: PyGame-Learning-Environment/ple/games/doom/assets/cfg/predict_position.cfg
#   inflating: PyGame-Learning-Environment/ple/games/doom/assets/cfg/health_gathering.cfg
#   inflating: PyGame-Learning-Environment/ple/games/doom/assets/cfg/defend_the_center.cfg
#   inflating: PyGame-Learning-Environment/ple/games/doom/assets/cfg/take_cover.cfg
#   inflating: PyGame-Learning-Environment/ple/games/doom/assets/cfg/deadly_corridor.cfg
#   inflating: PyGame-Learning-Environment/ple/games/doom/assets/cfg/defend_the_line.cfg
#   inflating: PyGame-Learning-Environment/ple/games/doom/assets/cfg/deathmatch.cfg
#   inflating: PyGame-Learning-Environment/ple/games/doom/assets/cfg/basic.cfg
#   inflating: PyGame-Learning-Environment/ple/games/doom/assets/README.md
#   inflating: PyGame-Learning-Environment/ple/games/pong.py
#   inflating: PyGame-Learning-Environment/ple/games/waterworld.py
#    creating: PyGame-Learning-Environment/ple/games/monsterkong/
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/onBoard.py
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/board.py
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/person.py
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/LICENSE
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/wall.py
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/__init__.py
#    creating: PyGame-Learning-Environment/ple/games/monsterkong/__pycache__/
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/__pycache__/board.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/__pycache__/player.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/__pycache__/coin.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/__pycache__/person.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/__pycache__/onBoard.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/__pycache__/fireball.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/__pycache__/__init__.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/__pycache__/monsterPerson.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/monsterPerson.py
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/player.py
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/fireball.py
#    creating: PyGame-Learning-Environment/ple/games/monsterkong/assets/
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/wood_block.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/monster11.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/monster01.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/monsterstill0.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/monsterstill1.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/fireballdown.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/monster1.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/left2.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/monster0.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/monster2.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/asset_credits.txt
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/monster3.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/fireballright.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/ladder.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/background.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/left.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/princess.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/still.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/right2.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/monster31.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/coin5.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/coin4.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/coin1.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/monster21.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/right.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/fireballleft.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/coin3.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/monsterstill10.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/monsterstill11.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/assets/coin2.png
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/coin.py
#   inflating: PyGame-Learning-Environment/ple/games/monsterkong/ladder.py
#    creating: PyGame-Learning-Environment/ple/games/flappybird/
#   inflating: PyGame-Learning-Environment/ple/games/flappybird/.DS_Store
#    creating: __MACOSX/PyGame-Learning-Environment/ple/games/flappybird/
#   inflating: __MACOSX/PyGame-Learning-Environment/ple/games/flappybird/._.DS_Store
#   inflating: PyGame-Learning-Environment/ple/games/flappybird/__init__.py
#   inflating: __MACOSX/PyGame-Learning-Environment/ple/games/flappybird/.___init__.py
#    creating: PyGame-Learning-Environment/ple/games/flappybird/__pycache__/
#   inflating: PyGame-Learning-Environment/ple/games/flappybird/__pycache__/__init__.cpython-37.pyc
#    creating: PyGame-Learning-Environment/ple/games/flappybird/assets/
#   inflating: PyGame-Learning-Environment/ple/games/flappybird/assets/redbird-downflap.png
#   inflating: PyGame-Learning-Environment/ple/games/flappybird/assets/pipe-red.png
#   inflating: PyGame-Learning-Environment/ple/games/flappybird/assets/pipe-ladder.png
#    creating: __MACOSX/PyGame-Learning-Environment/ple/games/flappybird/assets/
#   inflating: __MACOSX/PyGame-Learning-Environment/ple/games/flappybird/assets/._pipe-ladder.png
#   inflating: PyGame-Learning-Environment/ple/games/flappybird/assets/background-day.png
#   inflating: PyGame-Learning-Environment/ple/games/flappybird/assets/redbird-midflap.png
#   inflating: PyGame-Learning-Environment/ple/games/flappybird/assets/bluebird-midflap.png
#   inflating: PyGame-Learning-Environment/ple/games/flappybird/assets/background-noaffordances.png
#   inflating: __MACOSX/PyGame-Learning-Environment/ple/games/flappybird/assets/._background-noaffordances.png
#   inflating: PyGame-Learning-Environment/ple/games/flappybird/assets/yellowbird-upflap.png
#   inflating: PyGame-Learning-Environment/ple/games/flappybird/assets/bluebird-upflap.png
#   inflating: PyGame-Learning-Environment/ple/games/flappybird/assets/background-night.png
#   inflating: PyGame-Learning-Environment/ple/games/flappybird/assets/redbird-upflap.png
#   inflating: PyGame-Learning-Environment/ple/games/flappybird/assets/yellowbird-midflap.png
#   inflating: PyGame-Learning-Environment/ple/games/flappybird/assets/yellowbird-downflap.png
#   inflating: PyGame-Learning-Environment/ple/games/flappybird/assets/pipe-green.png
#   inflating: PyGame-Learning-Environment/ple/games/flappybird/assets/bluebird-downflap.png
#   inflating: PyGame-Learning-Environment/ple/games/flappybird/assets/base.png
#   inflating: PyGame-Learning-Environment/ple/games/catcher.py
#    creating: PyGame-Learning-Environment/ple/games/base/
#   inflating: PyGame-Learning-Environment/ple/games/base/.DS_Store
#    creating: __MACOSX/PyGame-Learning-Environment/ple/games/base/
#   inflating: __MACOSX/PyGame-Learning-Environment/ple/games/base/._.DS_Store
#   inflating: PyGame-Learning-Environment/ple/games/base/__init__.py
#    creating: PyGame-Learning-Environment/ple/games/base/__pycache__/
#   inflating: PyGame-Learning-Environment/ple/games/base/__pycache__/doomwrapper.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/base/__pycache__/pygamewrapper.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/base/__pycache__/__init__.cpython-37.pyc
#   inflating: PyGame-Learning-Environment/ple/games/base/doomwrapper.py
#   inflating: PyGame-Learning-Environment/ple/games/base/pygamewrapper.py
#   inflating: PyGame-Learning-Environment/ple/games/raycast.py
#   inflating: PyGame-Learning-Environment/random_agent.py
#    creating: PyGame-Learning-Environment/docker/
#   inflating: PyGame-Learning-Environment/docker/Dockerfile
#   inflating: PyGame-Learning-Environment/docker/README.md
#   inflating: PyGame-Learning-Environment/.DS_Store
#   inflating: __MACOSX/PyGame-Learning-Environment/._.DS_Store
#   inflating: PyGame-Learning-Environment/LICENSE
#   inflating: PyGame-Learning-Environment/ple_games.jpg
#    creating: PyGame-Learning-Environment/ple.egg-info/
#   inflating: PyGame-Learning-Environment/ple.egg-info/PKG-INFO
#   inflating: PyGame-Learning-Environment/ple.egg-info/not-zip-safe
#   inflating: PyGame-Learning-Environment/ple.egg-info/SOURCES.txt
#   inflating: PyGame-Learning-Environment/ple.egg-info/requires.txt
#   inflating: PyGame-Learning-Environment/ple.egg-info/top_level.txt
#   inflating: PyGame-Learning-Environment/ple.egg-info/dependency_links.txt
#    creating: PyGame-Learning-Environment/tests/
#   inflating: PyGame-Learning-Environment/tests/test_ple.py
#   inflating: PyGame-Learning-Environment/tests/test_ple_doom.py
#    creating: PyGame-Learning-Environment/docs/
#   inflating: PyGame-Learning-Environment/docs/index.rst
#   inflating: PyGame-Learning-Environment/docs/Makefile
#   inflating: PyGame-Learning-Environment/docs/conf.py
#    creating: PyGame-Learning-Environment/docs/_static/
#   inflating: PyGame-Learning-Environment/docs/_static/pong.gif
#   inflating: PyGame-Learning-Environment/docs/_static/monsterkong.gif
#   inflating: PyGame-Learning-Environment/docs/_static/raycastmaze.gif
#   inflating: PyGame-Learning-Environment/docs/_static/pixelcopter.gif
#   inflating: PyGame-Learning-Environment/docs/_static/snake.gif
#   inflating: PyGame-Learning-Environment/docs/_static/flappybird.gif
#   inflating: PyGame-Learning-Environment/docs/_static/waterworld.gif
#   inflating: PyGame-Learning-Environment/docs/_static/catcher.gif
#   inflating: PyGame-Learning-Environment/docs/_static/puckworld.gif
#   inflating: PyGame-Learning-Environment/docs/_static/doom.gif
#    creating: PyGame-Learning-Environment/docs/user/
#    creating: PyGame-Learning-Environment/docs/user/tutorial/
#   inflating: PyGame-Learning-Environment/docs/user/tutorial/assumed_knowledge.rst
#   inflating: PyGame-Learning-Environment/docs/user/tutorial/ple_keras.rst
#   inflating: PyGame-Learning-Environment/docs/user/tutorial/non_visual_state.rst
#   inflating: PyGame-Learning-Environment/docs/user/tutorial/ple_gen_dql.rst
#   inflating: PyGame-Learning-Environment/docs/user/tutorial/adding_pygame_games.rst
#   inflating: PyGame-Learning-Environment/docs/user/home.rst
#   inflating: PyGame-Learning-Environment/docs/user/tutorial.rst
#   inflating: PyGame-Learning-Environment/docs/user/games.rst
#    creating: PyGame-Learning-Environment/docs/user/games/
#   inflating: PyGame-Learning-Environment/docs/user/games/waterworld.rst
#   inflating: PyGame-Learning-Environment/docs/user/games/flappybird.rst
#   inflating: PyGame-Learning-Environment/docs/user/games/doom.rst
#   inflating: PyGame-Learning-Environment/docs/user/games/catcher.rst
#   inflating: PyGame-Learning-Environment/docs/user/games/puckworld.rst
#   inflating: PyGame-Learning-Environment/docs/user/games/raycastmaze.rst
#   inflating: PyGame-Learning-Environment/docs/user/games/pixelcopter.rst
#   inflating: PyGame-Learning-Environment/docs/user/games/pong.rst
#   inflating: PyGame-Learning-Environment/docs/user/games/monsterkong.rst
#   inflating: PyGame-Learning-Environment/docs/user/games/snake.rst
#    creating: PyGame-Learning-Environment/docs/modules/
#   inflating: PyGame-Learning-Environment/docs/modules/ple.rst
#   inflating: PyGame-Learning-Environment/docs/modules/base.rst
#   inflating: PyGame-Learning-Environment/README.md
#   inflating: PyGame-Learning-Environment/setup.py
#   inflating: PyGame-Learning-Environment/requirements-dev.txt
#   inflating: PyGame-Learning-Environment/.gitignore
#    creating: PyGame-Learning-Environment/examples/
#   inflating: PyGame-Learning-Environment/examples/random_agent.py
#   inflating: PyGame-Learning-Environment/examples/example_doom.py
#   inflating: PyGame-Learning-Environment/examples/keras_nonvis.py
#   inflating: PyGame-Learning-Environment/examples/example_support.py
#   inflating: PyGame-Learning-Environment/examples/scaling_rewards.py
#   inflating: PyGame-Learning-Environment/examples/screen_capture.png
#    creating: PyGame-Learning-Environment/.git/
#   inflating: PyGame-Learning-Environment/.git/config
#    creating: PyGame-Learning-Environment/.git/objects/
#    creating: PyGame-Learning-Environment/.git/objects/pack/
#   inflating: PyGame-Learning-Environment/.git/objects/pack/pack-00c877175f01e910541d18086fbdb97e23b74b6a.pack
#   inflating: PyGame-Learning-Environment/.git/objects/pack/pack-00c877175f01e910541d18086fbdb97e23b74b6a.idx
#    creating: PyGame-Learning-Environment/.git/objects/info/
#   inflating: PyGame-Learning-Environment/.git/HEAD
#    creating: PyGame-Learning-Environment/.git/info/
#   inflating: PyGame-Learning-Environment/.git/info/exclude
#    creating: PyGame-Learning-Environment/.git/logs/
#   inflating: PyGame-Learning-Environment/.git/logs/HEAD
#    creating: PyGame-Learning-Environment/.git/logs/refs/
#    creating: PyGame-Learning-Environment/.git/logs/refs/heads/
#   inflating: PyGame-Learning-Environment/.git/logs/refs/heads/master
#    creating: PyGame-Learning-Environment/.git/logs/refs/remotes/
#    creating: PyGame-Learning-Environment/.git/logs/refs/remotes/origin/
#   inflating: PyGame-Learning-Environment/.git/logs/refs/remotes/origin/HEAD
#   inflating: PyGame-Learning-Environment/.git/description
#    creating: PyGame-Learning-Environment/.git/hooks/
#   inflating: PyGame-Learning-Environment/.git/hooks/commit-msg.sample
#   inflating: PyGame-Learning-Environment/.git/hooks/pre-rebase.sample
#   inflating: PyGame-Learning-Environment/.git/hooks/pre-commit.sample
#   inflating: PyGame-Learning-Environment/.git/hooks/applypatch-msg.sample
#   inflating: PyGame-Learning-Environment/.git/hooks/fsmonitor-watchman.sample
#   inflating: PyGame-Learning-Environment/.git/hooks/pre-receive.sample
#   inflating: PyGame-Learning-Environment/.git/hooks/prepare-commit-msg.sample
#   inflating: PyGame-Learning-Environment/.git/hooks/post-update.sample
#   inflating: PyGame-Learning-Environment/.git/hooks/pre-applypatch.sample
#   inflating: PyGame-Learning-Environment/.git/hooks/pre-push.sample
#   inflating: PyGame-Learning-Environment/.git/hooks/update.sample
#    creating: PyGame-Learning-Environment/.git/refs/
#    creating: PyGame-Learning-Environment/.git/refs/heads/
#   inflating: PyGame-Learning-Environment/.git/refs/heads/master
#    creating: PyGame-Learning-Environment/.git/refs/tags/
#    creating: PyGame-Learning-Environment/.git/refs/remotes/
#    creating: PyGame-Learning-Environment/.git/refs/remotes/origin/
#   inflating: PyGame-Learning-Environment/.git/refs/remotes/origin/HEAD
#   inflating: PyGame-Learning-Environment/.git/index
#   inflating: PyGame-Learning-Environment/.git/packed-refs
#    creating: PyGame-Learning-Environment/gym-ple/
#   inflating: PyGame-Learning-Environment/gym-ple/.DS_Store
#    creating: __MACOSX/PyGame-Learning-Environment/gym-ple/
#   inflating: __MACOSX/PyGame-Learning-Environment/gym-ple/._.DS_Store
#   inflating: PyGame-Learning-Environment/gym-ple/LICENSE
#   inflating: PyGame-Learning-Environment/gym-ple/setup.py
#    creating: PyGame-Learning-Environment/gym-ple/gym_ple.egg-info/
#   inflating: PyGame-Learning-Environment/gym-ple/gym_ple.egg-info/PKG-INFO
#   inflating: PyGame-Learning-Environment/gym-ple/gym_ple.egg-info/not-zip-safe
#   inflating: PyGame-Learning-Environment/gym-ple/gym_ple.egg-info/SOURCES.txt
#   inflating: PyGame-Learning-Environment/gym-ple/gym_ple.egg-info/top_level.txt
#   inflating: PyGame-Learning-Environment/gym-ple/gym_ple.egg-info/dependency_links.txt
#   inflating: PyGame-Learning-Environment/gym-ple/README.rst
#    creating: PyGame-Learning-Environment/gym-ple/.git/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/config
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/3e/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/3e/35d653d6a27794f0d88a1c4e55dc820bfe1301
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/3c/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/3c/39ba25c10a48f8a47e333cd4f375b34cae3e94
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/3d/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/3d/3f8c378ddbca2997747f86a376672db2000cc9
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/67/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/67/27621e36846d824b47eadca483c5b3e74b06a6
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/60/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/60/fa6b68f1833d70d627120ea166abcf98e043bf
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/5f/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/5f/1ee555431b447d2a7d5a3a0501b2d20cdb6463
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/33/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/33/d84eda9c783c6ec68b4e92b85941d6ced447a2
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/05/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/05/b73b7f666f392ae4f0cfc9475e0ba1ca6eb0d9
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/9c/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/9c/1d320f887194b73dc6520f4dc7156b740e1fe4
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/b5/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/b5/b71a4d8b6920fe80c725ddd1c6f44d46c0ba34
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/ad/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/ad/32105e815c21b5ff7651b8947d98cacb634c65
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/d7/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/d7/b646ac40ac005fa3c6739762bb968387f308f8
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/d7/5b96fa69a6fc76ca4c250fa55621a3b135ef62
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/d7/9edd9a9c57af9009163f11a8ade8ca2c636b3d
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/be/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/be/5485fbef39ae409a18cea7c573f3ca00484330
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/be/db3a046eba203b519a85eaa54c2e23b1391dfd
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/df/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/df/11bc8566b22011f635f4f74331fbc79fb3a9de
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/da/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/da/9e18c6ad7c63b729a126b2d925c33f4adc47e7
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/da/39c766764e02ddade23c3b0ec9b9377c4db07e
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/d1/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/d1/c615d281a925c901079bc7641245ab1d2d7018
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/d8/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/d8/89b5c48675e4a0996d77942d7eff06666b7223
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/f4/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/f4/b75de054464d10ba9d1a0d719c9177617e1ede
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/c7/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/c7/3c19628d9f30ce5b45f2d5ec8b45a30944384d
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/c9/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/c9/f8c0b9b84857464d06e5f4c5da27ed53f9d0df
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/fd/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/fd/764439aeea17159f60b36d39fb140951eed25b
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/f5/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/f5/ed89ec4602c70b5846c48f02cef76fad3983e1
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/e3/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/e3/92abcc2630e0f11b363e70fa79eeffb9b21348
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/ca/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/ca/c0d6fc74bfb34cafd5b18392376c2a82931fdf
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/e4/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/e4/9a03cfe5a92871e250e27633e62eda0faa93e6
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/fb/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/fb/cd225a74d0a46ad03c9c65f874e7eed7066963
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/ed/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/ed/588e05d0abe6a042532b940b15ef7d2257a0bd
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/c1/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/c1/889987219c20b2aa622b37c8c9b8a8821821b8
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/ec/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/ec/499f4e9828e52b21aca9f55953379cad09879e
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/4e/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/4e/0eaaf3abf52ec9ca205ec04eea437ddbac54a1
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/20/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/20/193885f372ff7a19d5f0cafcd2cdcd70eb6d9f
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/20/d7c4113a96c92f8353761da2c2a00ed7a35e0e
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/18/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/18/7f5462940fc304090a3184f99a4eeec1f1cbed
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/18/294f77506195e54020c8c46254c121b03a9fdb
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/pack/
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/7d/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/7d/3db128c80ce7d1d3b8b834b0c516570eb94ad7
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/16/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/16/50080d53bbba1d95123494300f5c8a664adda7
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/45/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/45/ebc592b537aa2c0da66d4e05e3346ebdce41d7
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/87/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/87/437623e4e784a4d843a8f4d79ea54fc7c8c54c
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/80/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/80/963d458a3862fed3c1447fce48a5ad8042f2b5
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/80/8904347552bdb07c2b6e01c0e50ee5b7221641
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/74/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/74/7a1f877df35b9fbb67128058feddc2139a2c67
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/17/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/17/32035e73fd19ff24900cc89d1ffd0c89c42efe
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/19/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/19/35f9a56d170befe16f1e98e7018d9f23d2eb1d
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/4c/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/4c/a42294f695b5054a126ff427588675f8dd79c7
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/4d/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/4d/85c26c03b531bf7e88cd31d0449daa083ee24c
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/81/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/81/2a288aaf8b577e501cf66d421222ae836dab8d
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/86/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/86/4f299d83290b817beffbb5455aaccb8df56933
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/72/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/72/09c4d3ffe25baae2ef06d07f7af8e1910fbd63
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/72/6b055a30b0167ac545f4cd736d8a6923964583
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/44/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/44/1a02f39620f659fc78d06f867e3bccff28b96f
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/43/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/43/1d656a7dae11fc3b424d1f522e438ad80da389
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/38/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/38/7d89e601362f0f4b0ab7e90eea5405427c032b
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/00/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/00/3a78d47c4c95225b569ed74b7d2c315f631f45
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/36/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/36/b7a3154a188120bdb7118079768119a4b75321
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/36/47151d950fc461fd8e96ce421d41f37dc14c06
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/info/
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/3a/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/3a/3b20c49b3e516e4d32519669e6d34be6cd2964
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/53/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/53/a18d8f48780143e078f8087b07e389bd8c1af1
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/5e/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/5e/7a6b834106d5e7c0f90c274244abe4ff0988cc
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/5b/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/5b/2b5ec4f7e0e0e76845c59c1a8b2327f327c73e
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/5b/351fba9a75251a4685fd93f2a58787df18e381
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/37/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/37/198aa0db586cfb24503cb569c99fb8c2baacff
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/06/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/06/ae2f98a7cd3a5c4de38bdf0c8070a5b2a2deb1
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/39/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/39/3f88e64f6a1a8c18fe80703413ff8c7b538f14
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/90/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/90/0b3cbb6a57edc891b0df3109ab63dc5fbec4a3
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/a0/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/a0/5b2da99c89cffdd90469475bd52a08887c4aa0
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/b1/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/b1/5567ec2864aa0d63f1670dbbd0a5be9b9a2e72
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/a9/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/a9/58ccb5573b367492415b5dbb31b2552f818991
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/a9/3f48f75e0d3023597d1af3b020481bada4b06a
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/d5/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/d5/fcd05f10256e6488ba87cba5a3bde9394126de
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/aa/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/aa/111a5e1ecf1b147e38191e32967492300f905a
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/a8/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/a8/65c39ac030435f23378ec780470a4e92e9aec1
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/de/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/de/cbd690a8c16ad6004e6f1fdd6e24b780a7d270
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/b0/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/b0/279a2a647516ca2e15c82028d25d6bd6a6aae9
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/b9/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/b9/39ee8fd19a2ace7ee7db795b7105fafd9df0c4
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/b9/bbc9a0dbdabc76513d98daec8aed689e2b9c15
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/ef/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/ef/c4087e4c0f44ee02c45fbd4fd9d485e9713e72
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/ef/012b2b274ea184fa5cfb9de97e32ac49cc89a0
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/e1/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/e1/f57553a6d9bb132bdd2b9520d8f46d334c8b5d
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/f0/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/f0/c3d6e3f3fc31f82baa33ee7dff59303a80516d
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/e7/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/e7/194b5e173683e053d72e7185946dd52eb10e64
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/ce/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/ce/e6c43bcfa73b444db95e7ad09d850d9e5e222c
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/e0/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/e0/f8943d0c23389dce5c7acbd327fcc8e0a35271
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/2c/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/2c/847b1fa12d083ed7b2830cbbf9c417b394c8ed
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/2d/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/2d/00f95f37305776a67f69714c0bff66126a4827
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/2d/2a7ffe62d5c180d25ed76d227028d3972b3eb1
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/1b/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/1b/61e07b3792d1494c636c7f8c733d3644d8ff15
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/4a/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/4a/61f02480e94b88075aa21ba8d4619e83c45119
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/76/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/76/5e287d506f61509111093c9177434edf346456
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/1c/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/1c/5cae82964ec6fb0be16fd4bd0f4a99dbabeee4
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/1c/dcd211bd977433c9d8f9b2f88cb3ec341ad098
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/2b/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/2b/b1e617f925cbaeca692d86f0c32f4387172946
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/7a/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/7a/0ef98688f6d67947443881df667eb6111b1d0b
#    creating: PyGame-Learning-Environment/gym-ple/.git/objects/22/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/objects/22/c0518860b50cc4869b8d52d2a46439508481e0
#   inflating: PyGame-Learning-Environment/gym-ple/.git/HEAD
#    creating: PyGame-Learning-Environment/gym-ple/.git/info/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/info/exclude
#    creating: PyGame-Learning-Environment/gym-ple/.git/logs/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/logs/HEAD
#    creating: PyGame-Learning-Environment/gym-ple/.git/logs/refs/
#    creating: PyGame-Learning-Environment/gym-ple/.git/logs/refs/heads/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/logs/refs/heads/master
#    creating: PyGame-Learning-Environment/gym-ple/.git/logs/refs/remotes/
#    creating: PyGame-Learning-Environment/gym-ple/.git/logs/refs/remotes/origin/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/logs/refs/remotes/origin/HEAD
#   inflating: PyGame-Learning-Environment/gym-ple/.git/description
#    creating: PyGame-Learning-Environment/gym-ple/.git/hooks/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/hooks/commit-msg.sample
#   inflating: PyGame-Learning-Environment/gym-ple/.git/hooks/pre-rebase.sample
#   inflating: PyGame-Learning-Environment/gym-ple/.git/hooks/pre-commit.sample
#   inflating: PyGame-Learning-Environment/gym-ple/.git/hooks/applypatch-msg.sample
#   inflating: PyGame-Learning-Environment/gym-ple/.git/hooks/fsmonitor-watchman.sample
#   inflating: PyGame-Learning-Environment/gym-ple/.git/hooks/pre-receive.sample
#   inflating: PyGame-Learning-Environment/gym-ple/.git/hooks/prepare-commit-msg.sample
#   inflating: PyGame-Learning-Environment/gym-ple/.git/hooks/post-update.sample
#   inflating: PyGame-Learning-Environment/gym-ple/.git/hooks/pre-applypatch.sample
#   inflating: PyGame-Learning-Environment/gym-ple/.git/hooks/pre-push.sample
#   inflating: PyGame-Learning-Environment/gym-ple/.git/hooks/update.sample
#    creating: PyGame-Learning-Environment/gym-ple/.git/refs/
#    creating: PyGame-Learning-Environment/gym-ple/.git/refs/heads/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/refs/heads/master
#    creating: PyGame-Learning-Environment/gym-ple/.git/refs/tags/
#    creating: PyGame-Learning-Environment/gym-ple/.git/refs/remotes/
#    creating: PyGame-Learning-Environment/gym-ple/.git/refs/remotes/origin/
#   inflating: PyGame-Learning-Environment/gym-ple/.git/refs/remotes/origin/HEAD
#   inflating: PyGame-Learning-Environment/gym-ple/.git/index
#   inflating: PyGame-Learning-Environment/gym-ple/.git/packed-refs
#    creating: PyGame-Learning-Environment/gym-ple/gym_ple/
#   inflating: PyGame-Learning-Environment/gym-ple/gym_ple/ple_env.py
#   inflating: PyGame-Learning-Environment/gym-ple/gym_ple/.DS_Store
#    creating: __MACOSX/PyGame-Learning-Environment/gym-ple/gym_ple/
#   inflating: __MACOSX/PyGame-Learning-Environment/gym-ple/gym_ple/._.DS_Store
#   inflating: PyGame-Learning-Environment/gym-ple/gym_ple/__init__.py
#   inflating: PyGame-Learning-Environment/gym-ple/gym_ple/example.py
#   inflating: PyGame-Learning-Environment/screen_capture.png

# %%
# !ls
# Out:
# __MACOSX		     PyGame-Learning-Environment.zip
# PyGame-Learning-Environment  sample_data

# %%
# !apt-get install -y xvfb python-pygame python-opengl

import os

# !pip install pygame

#!git clone https://github.com/ntasfi/PyGame-Learning-Environment.git
os.chdir('PyGame-Learning-Environment/')
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-freefont-ttf libfluidsynth1 libmad0 libmikmod3 libportmidi0
#   libsdl-image1.2 libsdl-mixer1.2 libsdl-ttf2.0-0 libsdl1.2debian libsmpeg0
#   timgm6mb-soundfont
# Suggested packages:
#   libgle3 timidity fluid-soundfont-gm fluidsynth musescore
# The following NEW packages will be installed:
#   fonts-freefont-ttf libfluidsynth1 libmad0 libmikmod3 libportmidi0
#   libsdl-image1.2 libsdl-mixer1.2 libsdl-ttf2.0-0 libsdl1.2debian libsmpeg0
#   python-opengl python-pygame timgm6mb-soundfont xvfb
# 0 upgraded, 14 newly installed, 0 to remove and 29 not upgraded.
# Need to get 13.3 MB of archives.
# After this operation, 33.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-freefont-ttf all 20120503-7 [4,202 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfluidsynth1 amd64 1.1.9-1 [137 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libmad0 amd64 0.15.1b-9ubuntu18.04.1 [64.6 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmikmod3 amd64 3.3.11.1-3 [113 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libportmidi0 amd64 1:217-6 [17.8 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsdl1.2debian amd64 1.2.15+dfsg2-0.1ubuntu0.1 [175 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsdl-image1.2 amd64 1.2.12-8ubuntu0.1 [30.3 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsdl-mixer1.2 amd64 1.2.12-14 [72.0 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsdl-ttf2.0-0 amd64 2.0.11-4 [15.0 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsmpeg0 amd64 0.4.5+cvs20030824-7.2 [80.0 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-opengl all 3.1.0+dfsg-1 [496 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-pygame amd64 1.9.1release+dfsg-10build1 [1,662 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/universe amd64 timgm6mb-soundfont all 1.3-2 [5,423 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.4 [784 kB]
# Fetched 13.3 MB in 2s (5,957 kB/s)
# Selecting previously unselected package fonts-freefont-ttf.
# (Reading database ... 144429 files and directories currently installed.)
# Preparing to unpack .../00-fonts-freefont-ttf_20120503-7_all.deb ...
# Unpacking fonts-freefont-ttf (20120503-7) ...
# Selecting previously unselected package libfluidsynth1:amd64.
# Preparing to unpack .../01-libfluidsynth1_1.1.9-1_amd64.deb ...
# Unpacking libfluidsynth1:amd64 (1.1.9-1) ...
# Selecting previously unselected package libmad0:amd64.
# Preparing to unpack .../02-libmad0_0.15.1b-9ubuntu18.04.1_amd64.deb ...
# Unpacking libmad0:amd64 (0.15.1b-9ubuntu18.04.1) ...
# Selecting previously unselected package libmikmod3:amd64.
# Preparing to unpack .../03-libmikmod3_3.3.11.1-3_amd64.deb ...
# Unpacking libmikmod3:amd64 (3.3.11.1-3) ...
# Selecting previously unselected package libportmidi0:amd64.
# Preparing to unpack .../04-libportmidi0_1%3a217-6_amd64.deb ...
# Unpacking libportmidi0:amd64 (1:217-6) ...
# Selecting previously unselected package libsdl1.2debian:amd64.
# Preparing to unpack .../05-libsdl1.2debian_1.2.15+dfsg2-0.1ubuntu0.1_amd64.deb ...
# Unpacking libsdl1.2debian:amd64 (1.2.15+dfsg2-0.1ubuntu0.1) ...
# Selecting previously unselected package libsdl-image1.2:amd64.
# Preparing to unpack .../06-libsdl-image1.2_1.2.12-8ubuntu0.1_amd64.deb ...
# Unpacking libsdl-image1.2:amd64 (1.2.12-8ubuntu0.1) ...
# Selecting previously unselected package libsdl-mixer1.2:amd64.
# Preparing to unpack .../07-libsdl-mixer1.2_1.2.12-14_amd64.deb ...
# Unpacking libsdl-mixer1.2:amd64 (1.2.12-14) ...
# Selecting previously unselected package libsdl-ttf2.0-0:amd64.
# Preparing to unpack .../08-libsdl-ttf2.0-0_2.0.11-4_amd64.deb ...
# Unpacking libsdl-ttf2.0-0:amd64 (2.0.11-4) ...
# Selecting previously unselected package libsmpeg0:amd64.
# Preparing to unpack .../09-libsmpeg0_0.4.5+cvs20030824-7.2_amd64.deb ...
# Unpacking libsmpeg0:amd64 (0.4.5+cvs20030824-7.2) ...
# Selecting previously unselected package python-opengl.
# Preparing to unpack .../10-python-opengl_3.1.0+dfsg-1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-1) ...
# Selecting previously unselected package python-pygame.
# Preparing to unpack .../11-python-pygame_1.9.1release+dfsg-10build1_amd64.deb ...
# Unpacking python-pygame (1.9.1release+dfsg-10build1) ...
# Selecting previously unselected package timgm6mb-soundfont.
# Preparing to unpack .../12-timgm6mb-soundfont_1.3-2_all.deb ...
# Unpacking timgm6mb-soundfont (1.3-2) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../13-xvfb_2%3a1.19.6-1ubuntu4.4_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.4) ...
# Setting up python-opengl (3.1.0+dfsg-1) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.4) ...
# Setting up libsdl1.2debian:amd64 (1.2.15+dfsg2-0.1ubuntu0.1) ...
# Setting up libmikmod3:amd64 (3.3.11.1-3) ...
# Setting up libsdl-ttf2.0-0:amd64 (2.0.11-4) ...
# Setting up libportmidi0:amd64 (1:217-6) ...
# Setting up libsmpeg0:amd64 (0.4.5+cvs20030824-7.2) ...
# Setting up libsdl-image1.2:amd64 (1.2.12-8ubuntu0.1) ...
# Setting up timgm6mb-soundfont (1.3-2) ...
# Setting up libmad0:amd64 (0.15.1b-9ubuntu18.04.1) ...
# Setting up fonts-freefont-ttf (20120503-7) ...
# Setting up libfluidsynth1:amd64 (1.1.9-1) ...
# Setting up libsdl-mixer1.2:amd64 (1.2.12-14) ...
# Setting up python-pygame (1.9.1release+dfsg-10build1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Collecting pygame
#   Downloading https://files.pythonhosted.org/packages/8e/24/ede6428359f913ed9cd1643dd5533aefeb5a2699cc95bea089de50ead586/pygame-1.9.6-cp36-cp36m-manylinux1_x86_64.whl (11.4MB)
#      |████████████████████████████████| 11.4MB 258kB/s
# Installing collected packages: pygame
# Successfully installed pygame-1.9.6

# %%
# !pwd
# !pip install -e .
# Out:
# /content/PyGame-Learning-Environment
# Obtaining file:///content/PyGame-Learning-Environment
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from ple==0.0.1) (1.18.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from ple==0.0.1) (7.0.0)
# Installing collected packages: ple
#   Running setup.py develop for ple
# Successfully installed ple

# %%
# !pip install pyvirtualdisplay pygame
# Out:
# Collecting pyvirtualdisplay
#   Downloading https://files.pythonhosted.org/packages/69/ec/8221a07850d69fa3c57c02e526edd23d18c7c05d58ed103e3b19172757c1/PyVirtualDisplay-0.2.5-py2.py3-none-any.whl
# Requirement already satisfied: pygame in /usr/local/lib/python3.6/dist-packages (1.9.6)
# Collecting EasyProcess
#   Downloading https://files.pythonhosted.org/packages/48/3c/75573613641c90c6d094059ac28adb748560d99bd27ee6f80cce398f404e/EasyProcess-0.3-py2.py3-none-any.whl
# Installing collected packages: EasyProcess, pyvirtualdisplay
# Successfully installed EasyProcess-0.3 pyvirtualdisplay-0.2.5

# %%
# !pwd
# Out:
# /content/PyGame-Learning-Environment

# %%
from PIL import Image    
from ple import PLE
from ple.games.flappybird import FlappyBird
#import gym
#from gym.wrappers import Monitor
#import gym_ple
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# couldn't import doomish
# Couldn't import doom

# %%
#!git clone https://github.com/lusob/gym-ple.git

# !pip install -e .

# !pip install gym
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !apt-get install x11-utils

# !pip install pyvirtualdisplay
# !pip install piglet
# Out:
# Obtaining file:///content/PyGame-Learning-Environment
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from ple==0.0.1) (1.18.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from ple==0.0.1) (7.0.0)
# Installing collected packages: ple
#   Found existing installation: ple 0.0.1
#     Can't uninstall 'ple'. No files were found to uninstall.
#   Running setup.py develop for ple
# Successfully installed ple
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (0.17.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym) (1.18.4)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gym) (1.12.0)
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.16.0)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-opengl is already the newest version (3.1.0+dfsg-1).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# xvfb is already the newest version (2:1.19.6-1ubuntu4.4).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libxxf86dga1
# Suggested packages:
#   mesa-utils
# The following NEW packages will be installed:
#   libxxf86dga1 x11-utils
# 0 upgraded, 2 newly installed, 0 to remove and 29 not upgraded.
# Need to get 209 kB of archives.
# After this operation, 711 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-utils amd64 7.7+3build1 [196 kB]
# Fetched 209 kB in 1s (194 kB/s)
# Selecting previously unselected package libxxf86dga1:amd64.
# (Reading database ... 147335 files and directories currently installed.)
# Preparing to unpack .../libxxf86dga1_2%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.4-1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../x11-utils_7.7+3build1_amd64.deb ...
# Unpacking x11-utils (7.7+3build1) ...
# Setting up libxxf86dga1:amd64 (2:1.1.4-1) ...
# Setting up x11-utils (7.7+3build1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.6/dist-packages (0.2.5)
# Requirement already satisfied: EasyProcess in /usr/local/lib/python3.6/dist-packages (from pyvirtualdisplay) (0.3)
# Collecting piglet
#   Downloading https://files.pythonhosted.org/packages/11/56/6840e5f45626dc7eb7cd5dff57d11880b3113723b3b7b1fb1fa537855b75/piglet-1.0.0-py2.py3-none-any.whl
# Collecting piglet-templates
#   Downloading https://files.pythonhosted.org/packages/d0/dc/d628dcdf0b38b8f230e9c2309bfa370d2e3fb95e9e9c260213d10fde91ac/piglet_templates-1.0.0-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 3.3MB/s
# Requirement already satisfied: astunparse in /usr/local/lib/python3.6/dist-packages (from piglet-templates->piglet) (1.6.3)
# Collecting Parsley
#   Downloading https://files.pythonhosted.org/packages/2b/d6/4fed8d65e28a970e1c5cb33ce9c7e22e3de745e1b2ae37af051ef16aea3b/Parsley-1.3-py2.py3-none-any.whl (88kB)
#      |████████████████████████████████| 92kB 8.1MB/s
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.6/dist-packages (from piglet-templates->piglet) (1.1.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.6/dist-packages (from piglet-templates->piglet) (19.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from astunparse->piglet-templates->piglet) (0.34.2)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from astunparse->piglet-templates->piglet) (1.12.0)
# Installing collected packages: Parsley, piglet-templates, piglet
# Successfully installed Parsley-1.3 piglet-1.0.0 piglet-templates-1.0.0

# %%
# !pwd
# Out:
# /content/PyGame-Learning-Environment

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd 
import torch.nn.functional as F

from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()
# Out:
# <Display cmd_param=['Xvfb', '-br', '-nolisten', 'tcp', '-screen', '0', '1400x900x24', ':1001'] cmd=['Xvfb', '-br', '-nolisten', 'tcp', '-screen', '0', '1400x900x24', ':1001'] oserror=None return_code=None stdout="None" stderr="None" timeout_happened=False>

# %%
# Commented out IPython magic to ensure Python compatibility.
import os
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY"))==0:
    # !bash ../xvfb start
#     %env DISPLAY=:1

# %%
os.chdir('gym-ple')

# %%
import logging
import os, sys

import gym
from gym.wrappers import Monitor
import gym_ple

# Commented out IPython magic to ensure Python compatibility.
from gym import logger as gymlogger
gymlogger.set_level(40) # error only
import tensorflow as tf
import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import glob
import io
import base64
from IPython.display import HTML
from IPython.display import clear_output

from IPython import display as ipythondisplay

# %%
def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")

# %%
def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

# %%
USE_CUDA = torch.cuda.is_available()
Variable = lambda *args, **kwargs: autograd.Variable(*args, **kwargs).cuda() if USE_CUDA else autograd.Variable(*args, **kwargs)

from google.colab import drive
drive.mount('/data/')
from pathlib import Path

base_dir=Path('/data/My Drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /data/

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Thu May 14 11:18:53 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    25W / 250W |     10MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import gym_ple

import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [16,9]
from collections import namedtuple
from itertools import count
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T
import warnings
warnings.simplefilter("ignore", DeprecationWarning)

# %%
ENV='FlappyBird-v0'

torch.manual_seed(0)
np.random.seed(0)

env = gym.make(ENV)
env = wrap_env(env)
env.seed(0)

# %%
# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display
plt.ion()

# %%
# if gpu is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from collections import deque

# %%
Transition = namedtuple('Transition',
                        ('state', 'action', 'reward', 'next_state', 'done'))

# %%
class PriorityReplayMemory:
    # modified from https://github.com/susantamoh84/Deep-Reinforcement-Learning-Hands-On/blob/master/Chapter07/bench/prio_buffer_bench.py
    def __init__(self, capacity, alpha=0.6, beta_start=0.4, beta_frames=100000):
        self.alpha = alpha
        self.buffer = deque(maxlen=capacity)
        self.priorities = deque(maxlen=capacity)
        
        self.beta_start = beta_start
        self.beta_frames = beta_frames
        self.frame = 1
        self.min_prio = 0.1
        
    def beta_by_frame(self):
        self.frame += 1
        return min(1.0, self.beta_start + self.frame * (1.0 - self.beta_start) / self.beta_frames)

    def __len__(self):
        return len(self.buffer)

    def push(self, sample):
        max_prio = max(self.priorities) if self.priorities else 1.0
        self.buffer.append(sample)
        self.priorities.append(max_prio ** self.alpha)

    def sample(self, batch_size):
        probs = np.array(self.priorities, dtype=np.float32) 
        probs /= probs.sum()
        total = len(self.buffer)
        indices = np.random.choice(total, batch_size, p=probs, replace=True)
        samples = [self.buffer[idx] for idx in indices]
        
        beta = self.beta_by_frame()
        
        weights = (total * probs[indices]) ** (-beta)
        weights /= weights.max()
        
        return samples, indices, torch.Tensor(weights).to(device)
    

    def update_priorities(self, batch_indices, batch_priorities):
        for idx, prio in zip(batch_indices, batch_priorities):
            self.priorities[idx] = (prio + self.min_prio)** self.alpha

# %%
class ReplayMemory:

    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, sample):
        """Saves a transition."""
        self.buffer.append(sample)

    def sample(self, batch_size):
        indices = np.random.choice(len(self.buffer), batch_size, replace=True)
        samples = [self.buffer[idx] for idx in indices]
        return samples, None, torch.Tensor([1/len(self.buffer) for _ in range(batch_size)]).to(device)
    
    def update_priorities(self, batch_indices, batch_priorities):
        pass
    
    def __len__(self):
        return len(self.buffer)

# %%
class DDQN4(nn.Module):
    # 4 frames,

    def __init__(self, h, w):
        super().__init__()
        self.conv1 = nn.Conv2d(4, 32, kernel_size=8, stride=4)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.bn3 = nn.BatchNorm2d(64)

        # Number of Linear input connections depends on output of conv2d layers
        # and therefore the input image size, so compute it.
        def conv2d_size_out(size, kernel_size = 6, stride = 2, padding=0):
            return (size - kernel_size +2*padding ) // stride  + 1
        convw = conv2d_size_out(conv2d_size_out(conv2d_size_out(w,8,4),4,2),3,1)
        convh = conv2d_size_out(conv2d_size_out(conv2d_size_out(h,8,4),4,2),3,1)

        linear_input_size = convw * convh * 64
        fc_output_size=512
        self.fc_val=nn.Linear(linear_input_size, fc_output_size)
        self.fc_adv=nn.Linear(linear_input_size, fc_output_size)
        self.val = nn.Linear(fc_output_size, 1)
        self.adv = nn.Linear(fc_output_size, N_ACTION)

    # Called with either one element to determine next action, or a batch
    # during optimization. Returns tensor([[left0exp,right0exp]...]).
    def forward(self, x):
        x = x.float()
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        
        x_val = F.relu(self.fc_val(x.view(x.size(0), -1)))
        x_adv = F.relu(self.fc_adv(x.view(x.size(0), -1)))
        val=self.val(x_val)
        adv=self.adv(x_adv)
        
        
        x=val+adv-adv.mean(1,keepdim=True)
        return x

# %%
process_pic = T.Compose([
                    T.ToPILImage(),
                    T.Grayscale(),
                    T.Resize((84,84)),
                    T.ToTensor(),
                        ])

# %%
def get_screen_flappy():
    # Returned screen requested by gym is 400x600x3, but is sometimes larger
    # such as 800x1200x3. Transpose it into torch order (CHW).
    screen = env.render(mode='rgb_array').transpose((2, 0, 1))
    _, screen_height, screen_width = screen.shape
    screen = screen[:, :int(screen_height * 0.8)]
    screen = screen.mean(0).astype('uint8')

    screen = torch.from_numpy(screen)
    
    screen = process_pic(screen.unsqueeze(0))
    screen = (screen*255).type(torch.uint8)

    return screen.unsqueeze(0).to(device)


get_screen=get_screen_flappy

# %%
BATCH_SIZE = 32
GAMMA = 0.99
EPS_START = 1
EPS_END = 0.005
ESP_END2 = 0.1
FRAME_SKIP = 2
EPS_DECAY = 300000
EPS_DECAY2 = 200000
LOG_DECAY = False
TARGET_UPDATE = 1000
PLOT_INTERVAL = 50
REPLAY_SIZE= 100000
SAVE_CHECKPOINT=500
FULL_RANDOM=40000
OBSERVE = 20000
LR = 1e-6
USE_PRIORITY_REPLAY = True
N_ACTION = env.action_space.n
USE_BONUS_REWARD = False
LIMIT_MAX_REWARD = 250
CLIP_NORM=0.5
TOTALDEATHS=0
TOTALTIME=0
TOTALEPISODES=0
TOTALNSTEPS=0
TOTALREWARDS=0
TOTALACTIONCOUNT=0

# %%
from torchsummary import summary

# %%
init_screen = get_screen()
_, _, screen_height, screen_width = init_screen.shape

policy_net = DDQN4(screen_height, screen_width).to(device)
target_net = DDQN4(screen_height, screen_width).to(device)
print(policy_net)
summary(policy_net, (4, 84, 84))
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(),lr=LR)
# optimizer = optim.RMSprop(policy_net.parameters(),lr=LR)
if USE_PRIORITY_REPLAY:
    memory = PriorityReplayMemory(REPLAY_SIZE)
else:
    memory = ReplayMemory(REPLAY_SIZE)
# Out:
# DDQN4(
#   (conv1): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc_val): Linear(in_features=3136, out_features=512, bias=True)
#   (fc_adv): Linear(in_features=3136, out_features=512, bias=True)
#   (val): Linear(in_features=512, out_features=1, bias=True)
#   (adv): Linear(in_features=512, out_features=2, bias=True)
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 20, 20]           8,224
#        BatchNorm2d-2           [-1, 32, 20, 20]              64
#             Conv2d-3             [-1, 64, 9, 9]          32,832
#        BatchNorm2d-4             [-1, 64, 9, 9]             128
#             Conv2d-5             [-1, 64, 7, 7]          36,928
#        BatchNorm2d-6             [-1, 64, 7, 7]             128
#             Linear-7                  [-1, 512]       1,606,144
#             Linear-8                  [-1, 512]       1,606,144
#             Linear-9                    [-1, 1]             513
#            Linear-10                    [-1, 2]           1,026
# ================================================================
# Total params: 3,292,131
# Trainable params: 3,292,131
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.11
# Forward/backward pass size (MB): 0.33
# Params size (MB): 12.56
# Estimated Total Size (MB): 13.00
# ----------------------------------------------------------------

# %%
def select_action(state):
    global action_q
    policy_net.eval()
    sample = random.random()
    if LOG_DECAY:
        eps_threshold = EPS_END + (EPS_START - EPS_END) * math.exp(-1. * (steps_done - OBSERVE)/ EPS_DECAY)
    else:
        if not EPS_DECAY2:
            eps_threshold = max( EPS_START - (EPS_START - EPS_END)/EPS_DECAY *(steps_done - OBSERVE),EPS_END)
        else:
            # 0-EPS_DECAY: reduce threshold to EPS_END+ESP_END2, EPS_DECAY-EPS_DECAY2: reduce threshold to EPS_END
            if steps_done-OBSERVE<EPS_DECAY:
                eps_threshold = EPS_START - (EPS_START - EPS_END-ESP_END2)/EPS_DECAY *(steps_done - OBSERVE)
            else:
                eps_threshold = max( EPS_END+ESP_END2 - ESP_END2/EPS_DECAY2 *(steps_done - OBSERVE-EPS_DECAY),EPS_END)
                
    if not is_full_random() and sample > eps_threshold:
        with torch.no_grad():
            t=policy_net(state)
            action_q=t.max().item()
            return t.max(1)[1].view(1, 1)
    else:
        return torch.tensor([[random.randrange(N_ACTION)]], device=device, dtype=torch.long)

# %%
import time

def plot_durations():
    if i_episode%PLOT_INTERVAL==0:
        global action_qs
        plt.clf()
        display.clear_output(wait=True)
        rewards_t = torch.tensor(total_rewards, dtype=torch.float)
        bonus_rewards_t = torch.tensor(total_bonus_rewards, dtype=torch.float)
        action_qs_t = torch.tensor(action_qs, dtype=torch.float)
        plt.title('Training...episode:{},steps:{},time used:{}s'.format(i_episode,steps_done,round(time_used)))
        plt.xlabel('Episode')
        plt.ylabel('Duration')
#         plt.plot(action_qs_t.numpy(),label='Q')
        if USE_BONUS_REWARD:
            plt.plot(bonus_rewards_t.numpy(),label='bonus_reward')
        plt.plot(rewards_t.numpy(),label='reward')
        # Take 100 episode averages and plot them too
        if len(rewards_t) >= 100:
            means = rewards_t.unfold(0, 100, 1).mean(1).view(-1)
            means = torch.cat((torch.zeros(99), means))
            plt.plot(means.numpy(),label='reward_mean')
        if len(action_qs_t) >= 100:
            means = action_qs_t.unfold(0, 100, 1).mean(1).view(-1)
            means = torch.cat((torch.zeros(99), means))
            plt.plot(means.numpy(),label='Q_mean')
        plt.legend()
        plt.savefig(base_dir/'dqn'/'plot2.png')
        plt.pause(0.00001)  # pause a bit so that plots are updated
        plt.close()

# %%
def optimize_model():
    policy_net.train()
    if len(memory) < BATCH_SIZE:
        return
    if steps_done<OBSERVE:
        return
        
    samples, ids, weights = memory.sample(BATCH_SIZE)
    
    # Transpose the batch (see https://stackoverflow.com/a/19343/3343043 for
    # detailed explanation). This converts batch-array of Transitions
    # to Transition of batch-arrays.
    batch = Transition(*zip(*samples))
    

    # Compute a mask of non-final states and concatenate the batch elements
    # (a final state would've been the one after which simulation ended)
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.uint8)
    
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
    # columns of actions taken. These are the actions which would've been taken
    # for each batch state according to policy_net
    
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Compute V(s_{t+1}) for all next states.
    # Expected values of actions for non_final_next_states are computed based
    # on the "older" target_net; selecting their best reward with max(1)[0].
    # This is merged based on the mask, such that we'll have either the expected
    # state value or 0 in case the state was final.
    with torch.no_grad():
        next_state_values = torch.zeros(BATCH_SIZE, device=device)
        next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
        expected_state_action_values = (next_state_values * GAMMA) + reward_batch
    
    diff = state_action_values.squeeze() - expected_state_action_values.squeeze()
    loss=torch.zeros(diff.shape)
    for index,(i,j) in enumerate(zip(diff,weights)):
        if -1<i<1:
            loss[index]=(i * i)/2 * j
        else:
            loss[index]=(i.abs()-1/2)*j
    loss=loss.mean().to(device)
    
#     loss = F.mse_loss(state_action_values, expected_state_action_values.unsqueeze(1))
    
    delta = diff.abs().detach().cpu().numpy().tolist()
    memory.update_priorities(ids, delta)


    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    torch.nn.utils.clip_grad_norm_(policy_net.parameters(),CLIP_NORM)
    optimizer.step()

# %%
from collections import deque
import time
import os

from pathlib import Path



checkpoint_file=base_dir/'dqn'/'flappy_checkpoint2.pt'
temp_policy=base_dir/'dqn'/'best_score.pt'

# %%
def save_checkpoint():
    torch.save({
                'i_episode': i_episode+1,
                'total_rewards':total_rewards,
                'total_bonus_rewards':total_bonus_rewards,
                'steps_done':steps_done,
                'policy_state_dict': policy_net.state_dict(),
                'target_state_dict': target_net.state_dict(),
                'optimizer' : optimizer.state_dict(),
                'time_used' : time_used,
            },checkpoint_file)

def load_checkpoint():
    global i_episode,policy_net,optimizer,steps_done,memory,total_rewards,time_used,total_bonus_rewards
    if os.path.exists(checkpoint_file):
        checkpoint=torch.load(checkpoint_file)
        i_episode=checkpoint['i_episode']
        total_rewards=checkpoint['total_rewards']
        total_bonus_rewards=checkpoint['total_bonus_rewards']
        steps_done=checkpoint['steps_done']
        time_used=checkpoint['time_used']
        optimizer.load_state_dict(checkpoint['optimizer'])
        policy_net.load_state_dict(checkpoint['policy_state_dict'])
        target_net.load_state_dict(checkpoint['target_state_dict'])

# %%
resume=False

i_episode = 0
total_rewards = []
total_bonus_rewards = []
action_qs = []
steps_done = 0
time_used = 0
best_avg_score=-5
meanreward=0
flagval = False

# %%
if resume:
    load_checkpoint()
    
def is_key_frame(t):
    return t%FRAME_SKIP==0

def is_full_random():
    return steps_done<FULL_RANDOM

for i_episode in count(i_episode):
    # Initialize the environment and state
    TOTALEPISODES += 1
    start_time=time.time()
    env.reset()
    total_reward=0
    total_bonus_reward=0
    last_screen = get_screen()
    current_screen = get_screen()
    screens = deque([current_screen] * 4, 4)
    state = torch.cat(list(screens), dim=1)
    last_action=None
    key_frame_reward=0.0
    action_q=None
    episode_q=[]
    
    for t in count():
        # Select and perform an action
        steps_done += 1
        TOTALNSTEPS += 1
        if is_key_frame(t):
            action = select_action(state)
            last_action=action
            if action_q is not None:
                episode_q.append(action_q+total_reward)
        else:
            action=last_action
        _, reward, done, _ = env.step(action.item())
        #print(reward)
        #print(action.item())
        TOTALACTIONCOUNT += 1

        total_reward+=reward
        key_frame_reward+=reward
        total_bonus_reward+=reward+0.05

        if done:
            TOTALDEATHS += 1      
        
        # Observe new state
        last_screen = current_screen
        
        if is_key_frame(t) or done:
            current_screen = get_screen()
            screens.append(current_screen)
        if not done:
            next_state = torch.cat(list(screens), dim=1)
        else:
            next_state = None


        # Store the transition in memory
        if is_key_frame(t) or done:
            if USE_BONUS_REWARD:
                bonus_reward_t = torch.tensor([reward+0.05], device=device)
                memory.push(Transition(state, action, bonus_reward_t, next_state, done))
                
            else:
                key_frame_reward_t=torch.tensor([key_frame_reward], device=device)
                memory.push(Transition(state, action, key_frame_reward_t, next_state, done))
                key_frame_reward=0
            
            if LIMIT_MAX_REWARD and total_reward>LIMIT_MAX_REWARD:
                True

        # Move to the next state
        state = next_state

        # Perform one step of the optimization (on the target network)
        optimize_model()
        
        if done:
            total_rewards.append(total_reward)
            total_bonus_rewards.append(total_bonus_reward)
            meanreward =  sum(total_rewards)/len(total_rewards)
            if episode_q:
                action_qs.append(sum(episode_q)/len(episode_q))
            else:
                action_qs.append(0)
            plot_durations()
            break
            
        if steps_done % TARGET_UPDATE==0 and not is_full_random():
            target_net.load_state_dict(policy_net.state_dict())
        
#         if steps_done%100==0:
#             print(np.array(list(memory.priorities)).max(),np.array(list(memory.priorities)).mean(),len(memory.buffer))
    if i_episode and i_episode%SAVE_CHECKPOINT==0 and not is_full_random():
        save_checkpoint()
    if len(total_rewards)>100:
        last_100_avg_rewards=sum(total_rewards[-100:])/100
        if last_100_avg_rewards>best_avg_score:
            best_avg_score=last_100_avg_rewards
            torch.save(policy_net,temp_policy)
        
        
    time_used+=time.time()-start_time
    TOTALTIME+=time_used
    TOTALREWARDS+=total_reward
    print('total_reward: ',total_reward)
    if not flagval and total_reward>=3.00:
        flagval=True
        print(flagval)
        with open("log.txt",'w',encoding = 'utf-8') as f:
            f.write("meanreward = %f \n" %(meanreward))
            f.write("TOTALDEATHS = %f \n" %(TOTALDEATHS))
            f.write("TOTALTIME = %f \n" %(TOTALTIME))
            f.write("TOTALEPISODES = %f \n" %(TOTALEPISODES))
            f.write("TOTALNSTEPS = %f \n" %(TOTALNSTEPS))
            f.write("TOTALACTIONCOUNT = %f \n" %(TOTALACTIONCOUNT))
            f.write("Best average score:  = %f \n" %(best_avg_score))
            # f.write("flagval:  = %s \n" %(Boolean.toString(flagval)))

print('Complete')
env.render()
env.close()
# plt.ioff()
# plt.show()
show_video()
#print(sum(total_rewardsepisode_durations[-100:])/100)
# Out:
# total_reward:  -4.0
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# total_reward:  -4.0
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# total_reward:  -4.0
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# total_reward:  -5.0
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# total_reward:  -5.0
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# ...
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# total_reward:  -5.0
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# total_reward:  -5.0
# Buffered data was truncated after reaching the output size limit.

# %%
from google.colab import files
files.download('/content/original.zip')

# %%
# !zip -r /content/original.zip /content/PyGame-Learning-Environment/gym-ple/gym_ple/
# Out:
# 	zip warning: name not matched: /content/PyGame-Learning-Environment/gym-ple/gym_ple/
#
# zip error: Nothing to do! (try: zip -r /content/original.zip . -i /content/PyGame-Learning-Environment/gym-ple/gym_ple/)
